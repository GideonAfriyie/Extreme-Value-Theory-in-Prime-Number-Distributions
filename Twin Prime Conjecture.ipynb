# %%
def is_prime(n):
    if n < 2:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

primes = []
num = 2
while len(primes) < 1000:
    if is_prime(num):
        primes.append(num)
    num += 1

import csv
with open('first_1000_primes.csv', 'w', newline='') as f:
    writer = csv.writer(f)
    writer.writerow(['Prime Number'])
    for p in primes:
        writer.writerow([p])

print("first_1000_primes.csv")
# Out:
# first_1000_primes.csv

# %%
import matplotlib.pyplot as plt

twin_primes = [(p, p+2) for p in primes if (p + 2) in primes]
print(f"Total Twin Prime Pairs: {len(twin_primes)}")

ranges = [(0, 250), (251, 500), (501, 750), (751, 1000)]
range_counts = []
for r in ranges:
    count = sum(1 for p1, p2 in twin_primes if r[0] <= p1 <= r[1])
    range_counts.append(count)


labels = ['0-250', '251-500', '501-750', '751-1000']
plt.bar(labels, range_counts, color='green')
plt.title("Twin Prime Pair Count by Prime Range")
plt.ylabel("Twin Prime Count")
plt.show()
# Out:
# Total Twin Prime Pairs: 174
